# %%
# Required Dependencies

import pandas as pd
import numpy as np
import os

# %%
# Files to load and REad

CAL = "California_Merged_100k.csv"
cal = pd.read_csv(CAL)

# %%
# 'cal' details

cal.shape
# Out:
# (10000, 20)

# %%
# Index 'cal' by County

cal.set_index('County', inplace=True)

# %%
# set display options

pd.set_option('display.max_rows', 1)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.width', None)

# %%
# Print 'cal'

cal
# Out:
#                     Year  ST  AGEP  FER  GCL  HINS1  JWMNP  JWRIP  JWTR  LANX  \
# County
# Los Angeles County  2012   6    48  NaN  2.0      1   25.0    1.0   1.0   1.0
# ...                  ...  ..   ...  ...  ...    ...    ...    ...   ...   ...
#
#                     MAR  SCH  SCHG  SCHL     WAGP  WKHP  DIS  ESR  OC
# County
# Los Angeles County    1  1.0   NaN  13.0  29500.0  40.0    2  1.0   0
# ...                 ...  ...   ...   ...      ...   ...  ...  ...  ..
#
# [10000 rows x 19 columns]

# %%
# Remane 'cal' columns

cal.rename(columns = {'ST':'State', 'AGEP':'Age', 'FER': 'Gave birth to child within the past 12 months', 'GCL':'Grandparents living with grandchildren','HINS1':'Insurance through a current or former employer or union','JWMNP':'Travel time to work','JWRIP':'Vehicle occupancy','JWTR':'Means of transportation to work','LANX':'Language other than English spoken at home','MAR':'Marital status','JWRIP':'Vehicle occupancy','SCH':'School enrollment','SCHG':'Grade level attending','SCHL':'Educational attainment','WAGP':'Wages or salary income past 12 months','DIS':'Disability','ESR':'Employment status','OC':'Has Own Child','WKHP':'Usual hours worked per week past 12 months'}, inplace =True)
cal
# Out:
#                     Year  State  Age  \
# County
# Los Angeles County  2012      6   48
# ...                  ...    ...  ...
#
#                     Gave birth to child within the past 12 months  \
# County
# Los Angeles County                                            NaN
# ...                                                           ...
#
#                     Grandparents living with grandchildren  \
# County
# Los Angeles County                                     2.0
# ...                                                    ...
#
#                     Insurance through a current or former employer or union  \
# County
# Los Angeles County                                                        1
# ...                                                                     ...
#
#                     Travel time to work  Vehicle occupancy  \
# County
# Los Angeles County                 25.0                1.0
# ...                                 ...                ...
#
# ...

# %%
# save 'cal' to csv

cal.to_csv("California_Final_100k.csv")
