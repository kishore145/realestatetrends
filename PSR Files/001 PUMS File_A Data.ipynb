# %%
# Required Dependencies

import pandas as pd
import numpy as np
import os

# %%
# Files to load

file_1 = "ss16pus_a.csv"

# %%
# Read file 1

file_a = pd.read_csv(file_1)
file_a.shape
# Out:
# (4661257, 283)

# %%
# Print 'file_a'

file_a
# Out:
#         RT       SERIALNO  SPORDER   PUMA  ST   ADJINC  PWGTP  AGEP  CIT  \
# 0        P  2012000000002        1   1500   5  1056030      3    55    1
# 1        P  2012000000009        1   3005  13  1056030     22    74    1
# 2        P  2012000000009        2   3005  13  1056030     26    68    1
# 3        P  2012000000010        1    100  13  1056030     23    69    1
# 4        P  2012000000010        2    100  13  1056030     26    53    1
# 5        P  2012000000010        3    100  13  1056030     33    35    1
# 6        P  2012000000010        4    100  13  1056030     33    34    1
# 7        P  2012000000010        5    100  13  1056030     26    15    1
# 8        P  2012000000010        6    100  13  1056030     30    14    1
# 9        P  2012000000010        7    100  13  1056030     30    12    1
# 10       P  2012000000010        8    100  13  1056030     18     7    1
# 11       P  2012000000010        9    100  13  1056030     19     4    1
# ...

# %%
# Sort 'file_a' by California

cal1 = file_a[file_a.ST == 6]

# %%
# Print 'cal1'

cal1
# Out:
#         RT       SERIALNO  SPORDER   PUMA  ST   ADJINC  PWGTP  AGEP  CIT  \
# 14       P  2012000000011        1   8508   6  1056030     21    63    1
# 15       P  2012000000011        2   8508   6  1056030     22    60    1
# 21       P  2012000000022        1   8105   6  1056030     14    79    1
# 26       P  2012000000031        1   1305   6  1056030     20    49    1
# 27       P  2012000000031        2   1305   6  1056030     19    48    1
# 31       P  2012000000040        1   2901   6  1056030      2    60    1
# 32       P  2012000000040        2   2901   6  1056030      2    30    1
# 43       P  2012000000067        1   8511   6  1056030     16    50    1
# 47       P  2012000000071        1   7311   6  1056030     12    93    1
# 48       P  2012000000071        2   7311   6  1056030     20    36    1
# 52       P  2012000000076        1   7313   6  1056030      3    28    1
# 54       P  2012000000093        1   9703   6  1056030     12    59    1
# ...

# %%
# Saved cal1 to a new csv file

cal1.to_csv("California_1.csv")
